# %% [markdown]
# # Module 12 Challenge
# ## Deliverable 2: Scrape and Analyse Mars Weather Data

# %%
# Import relevant libraries
from splinter import Browser
from bs4 import BeautifulSoup as soup
import matplotlib.pyplot as plt
import pandas as pd
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
import os
from datetime import timezone, timedelta

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

# %% [markdown]
# ### Step 1: Visit the Website
#
# Use automated browsing to visit the [Mars Temperature Data Site](https://static.bc-edx.com/data/web/mars_facts/temperature.html). Inspect the page to identify which elements to scrape.
#
#    > **Hint** To identify which elements to scrape, you might want to inspect the page by using Chrome DevTools to discover whether the table contains usable classes.

# %%
# Visit the website
url1 = 'https://static.bc-edx.com/data/web/mars_facts/temperature.html' 
browser.visit(url1)

# %% [markdown]
# ### Step 2: Scrape the Table
#
# Create a Beautiful Soup object and use it to scrape the data in the HTML table.
#
# Note that this can also be achieved by using the Pandas `read_html` function. However, use Beautiful Soup here to continue sharpening your web scraping skills.

# %%
# Create a Beautiful Soup Object
html = browser.html
mars_soup = soup(html, 'html.parser')

# %%
# Extract all rows of data
mars_t_rows = mars_soup.find('table', class_='table')
print(mars_t_rows)
# Out:
# <table class="table">
# <tbody><tr>
# <th>id</th>
# <th>terrestrial_date</th>
# <th>sol</th>
# <th>ls</th>
# <th>month</th>
# <th>min_temp</th>
# <th>pressure</th>
# </tr>
# <tr class="data-row">
# <td>2</td>
# <td>2012-08-16</td>
# <td>10</td>
# <td>155</td>
# <td>6</td>
# <td>-75.0</td>
# <td>739.0</td>
# </tr>
# <tr class="data-row">
# <td>13</td>
# <td>2012-08-17</td>
# <td>11</td>
# <td>156</td>
# <td>6</td>
# <td>-76.0</td>
# <td>740.0</td>
# </tr>
# <tr class="data-row">
# <td>24</td>
# <td>2012-08-18</td>
# <td>12</td>
# <td>156</td>
# <td>6</td>
# <td>-76.0</td>
# <td>741.0</td>
# </tr>
# <tr class="data-row">
# <td>35</td>
# <td>2012-08-19</td>
# <td>13</td>
# <td>157</td>
# <td>6</td>
# <td>-74.0</td>
# <td>732.0</td>
# </tr>
# <tr class="data-row">
# <td>46</td>
# <td>2012-08-20</td>
# <td>14</td>
# <td>157</td>
# <td>6</td>
# <td>-74.0</td>
# <td>740.0</td>
# </tr>
# <tr class="data-row">
# <td>57</td>
# <td>2012-08-21</td>
# <td>15</td>
# <td>158</td>
# <td>6</td>
# ...

# %% [markdown]
# ### Step 3: Store the Data
#
# Assemble the scraped data into a Pandas DataFrame. The columns should have the same headings as the table on the website. Here’s an explanation of the column headings:
#
# * `id`: the identification number of a single transmission from the Curiosity rover
# * `terrestrial_date`: the date on Earth
# * `sol`: the number of elapsed sols (Martian days) since Curiosity landed on Mars
# * `ls`: the solar longitude
# * `month`: the Martian month
# * `min_temp`: the minimum temperature, in Celsius, of a single Martian day (sol)
# * `pressure`: The atmospheric pressure at Curiosity's location

# %%
# Create an empty list
columns = []
data = []

# Loop through the headings to create list of headings
headings = mars_t_rows.find_all('th')
for heading in headings:
    columns.append(heading.get_text())

# Loop through the scraped data to create a list of rows

rows = mars_t_rows.find_all('tr', class_='data-row')

for row in rows:
    items = []
    row_data = row.find_all('td')
    for result in row_data:
        items.append(result.text)
    data.append(items)

# %%
# Create a Pandas DataFrame by using the list of rows and a list of the column names
mars_df = pd.DataFrame(data,columns = columns)

# %%
# Confirm DataFrame was created successfully
mars_df
# Out:
#         id terrestrial_date   sol   ls month min_temp pressure
# 0        2       2012-08-16    10  155     6    -75.0    739.0
# 1       13       2012-08-17    11  156     6    -76.0    740.0
# 2       24       2012-08-18    12  156     6    -76.0    741.0
# 3       35       2012-08-19    13  157     6    -74.0    732.0
# 4       46       2012-08-20    14  157     6    -74.0    740.0
# ...    ...              ...   ...  ...   ...      ...      ...
# 1862  1889       2018-02-23  1973  133     5    -78.0    730.0
# 1863  1892       2018-02-24  1974  134     5    -77.0    729.0
# 1864  1894       2018-02-25  1975  134     5    -76.0    729.0
# 1865  1893       2018-02-26  1976  135     5    -77.0    728.0
# 1866  1895       2018-02-27  1977  135     5    -77.0    727.0
#
# [1867 rows x 7 columns]

# %% [markdown]
# ### Step 4: Prepare Data for Analysis
#
# Examine the data types that are currently associated with each column. If necessary, cast (or convert) the data to the appropriate `datetime`, `int`, or `float` data types.
#
#   > **Hint** You can use the Pandas `astype` and `to_datetime` methods to accomplish this task.

# %%
# Examine data type of each column
mars_df.dtypes
# Out:
# id                  object
# terrestrial_date    object
# sol                 object
# ls                  object
# month               object
# min_temp            object
# pressure            object
# dtype: object

# %%
# Change data types for data analysis
mars_df[mars_df.columns[1]] = pd.to_datetime(mars_df[mars_df.columns[1]])
mars_df[mars_df.columns[2]] = mars_df[mars_df.columns[2]].astype(int) 
mars_df[mars_df.columns[3]] = mars_df[mars_df.columns[3]].astype(int)
mars_df[mars_df.columns[4]] = mars_df[mars_df.columns[4]].astype(int) 
mars_df[mars_df.columns[5]] = mars_df[mars_df.columns[5]].astype(int) 
mars_df[mars_df.columns[6]] = mars_df[mars_df.columns[6]].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18524\1757066287.py in <module>
#       4 mars_df[mars_df.columns[3]] = mars_df[mars_df.columns[3]].astype(int)
#       5 mars_df[mars_df.columns[4]] = mars_df[mars_df.columns[4]].astype(int)
# ----> 6 mars_df[mars_df.columns[5]] = mars_df[mars_df.columns[5]].astype(int)
#       7 mars_df[mars_df.columns[6]] = mars_df[mars_df.columns[6]].astype(float)
#
# c:\Users\richa\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ...

# %%
# Confirm type changes were successful by examining data types again
mars_df.dtypes
# Out:
# id                          object
# terrestrial_date    datetime64[ns]
# sol                          int32
# ls                           int32
# month                        int32
# min_temp                     int32
# pressure                   float64
# dtype: object

# %% [markdown]
# ### Step 5: Analyse the Data
#
# Analyse your dataset by using Pandas functions to answer the following questions:
#
# 1. How many months exist on Mars?
# 2. How many Martian (and not Earth) days worth of data exist in the scraped dataset?
# 3. What are the coldest and the warmest months on Mars (at the location of Curiosity)? To answer this question:
#     * Find the average the minimum daily temperature for all of the months.
#     * Plot the results as a bar chart.
# 4. Which months have the lowest and the highest atmospheric pressure on Mars? To answer this question:
#     * Find the average the daily atmospheric pressure of all the months.
#     * Plot the results as a bar chart.
# 5. About how many terrestrial (Earth) days exist in a Martian year? To answer this question:
#     * Consider how many days elapse on Earth in the time that Mars circles the Sun once.
#     * Visually estimate the result by plotting the daily minimum temperature.

# %%
# 1. How many months are there on Mars?
mars_months = mars_df['month'].max()
print('Q1 how many months are there on mars?')
print(f'There are {mars_months} months on mars.')
# Out:
# Q1 how many months are there on mars?
# There are 12 months on mars.

# %%
# 2. How many Martian days' worth of data are there?
print('Q2 how many martian days of data are in the dataset?')
print (f"The number of Martian days on Mars: {mars_df['sol'].max()}")
# Out:
# Q2 how many martian days of data are in the dataset?
# The number of Martian days on Mars: 1977

# %%
# 3. What is the average low temperature by month?
mars_month_temp = mars_df[['month', 'min_temp']].groupby(by='month').mean()

mars_month_temp['min_temp'] = mars_month_temp['min_temp'].round(decimals = 2)

print('the average low temperature for each month is:')
mars_month_temp
# Out:
# the average low temperature for each month is:
#        min_temp
# month
# 1        -77.16
# 2        -79.93
# 3        -83.31
# 4        -82.75
# 5        -79.31
# 6        -75.30
# 7        -72.28
# 8        -68.38
# 9        -69.17
# 10       -71.98
# 11       -71.99
# 12       -74.45

# %%
# Plot the average temperature by month
fig, ax = plt.subplots(figsize=[8,7])
ax = plt.bar(mars_month_temp.index,mars_month_temp.min_temp)
plt.xticks(ticks = range(1,13))
plt.xlabel('Month')
plt.ylabel('Temperature (C)')
plt.title('Monthly Average Temperature')
plt.legend(['Average Min Temp'], loc='best')
plt.ylim(-100, 50)
plt.show()

# %%
# Identify the coldest and hottest months in Curiosity's location
coldest_month = mars_month_temp["min_temp"].idxmin()
coldest_month_temp = mars_month_temp["min_temp"].min()

hottest_month = mars_month_temp["min_temp"].idxmax()
hottest_month_temp = mars_month_temp["min_temp"].max()

print(f'the coldest month on mars is {coldest_month} with {coldest_month_temp}')
print(f'the hottest month on mars is {hottest_month} with {hottest_month_temp}')
# Out:
# the coldest month on mars is 3 with -83.31
# the hottest month on mars is 8 with -68.38

# %%
# 4. Average pressure by Martian month
mars_month_pressure = mars_df[['month','pressure']].groupby(by='month').mean()
mars_month_pressure['pressure'] = mars_month_pressure['pressure'].round(decimals = 2)
mars_month_pressure.head(12)
# Out:
#        pressure
# month
# 1        862.49
# 2        889.46
# 3        877.32
# 4        806.33
# 5        748.56
# 6        745.05
# 7        795.11
# 8        873.83
# 9        913.31
# 10       887.31
# 11       857.01
# 12       842.16

# %%
# Plot the average pressure by month
fig, ax = plt.subplots(figsize=[8,6])
ax = plt.bar(mars_month_pressure.index, mars_month_pressure.pressure)
plt.xticks(ticks = range(1,13))
plt.xlabel('Month')
plt.ylabel('Average Preassure')
plt.title('monthly Average Pressure')
plt.show()

# %%
# 5. How many terrestrial (earth) days are there in a Martian year?
fig, ax = plt.subplots(figsize=[14,7])
ax = plt.plot(mars_df.terrestrial_date, mars_df.min_temp)
plt.grid(visible=True, which='both')
plt.xlabel('Date')
plt.ylabel('Min Temp (C)')
plt.title('Min daily Temp on Mars')
plt.show()

print("from the visualisation it takes approximately 2 earth years for mars to complete its annual temperature cycle \nor an estimated at 700 days to complete a full rotation")
# Out:
# from the visualisation it takes approximately 2 earth years for mars to complete its annual temperature cycle
# or an estimated at 700 days to complete a full rotation

# %% [markdown]
# On average, the third month has the coldest minimum temperature on Mars, and the eighth month is the warmest. But it is always very cold there in human terms!

# %% [markdown]
# Atmospheric pressure is, on average, lowest in the sixth month and highest in the ninth.

# %% [markdown]
# The distance from peak to peak is roughly 1425-750, or 675 days. A year on Mars appears to be about 675 days from the plot. Internet search confirms that a Mars year is equivalent to 687 earth days.

# %% [markdown]
# ### Step 6: Save the Data
#
# Export the DataFrame to a CSV file.

# %%
# Write the data to a CSV
mars_df.to_csv("./Output/mars.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28144\1192484236.py in <module>
#       1 # Write the data to a CSV
# ----> 2 mars_df.to_csv("./Output/mars.csv")
#
# c:\Users\richa\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3202             decimal=decimal,
#    3203         )
# -> 3204         formatter.save()
#    3205
#    3206         if path_or_buf is None:
#
# c:\Users\richa\anaconda3\envs\PythonData\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     186                 self.mode,
#     187                 encoding=self.encoding,
# ...

# %%
browser.quit()
